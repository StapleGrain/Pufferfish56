# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import IPython.display

import librosa

import librosa.display

import scipy
from scipy.signal import periodogram

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Acoustic Guitar C4, 16.20.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Project 2 - 3:12:20, 3.24 PM.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/PHYS 2218 Lab Audio Files/Acoustic Guitar C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Acoustic Guitar C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Cathedral Organ C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Clarinet Solo C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Flute Solo C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Picked Bass C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Saxophone C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Steinway Grand Piano C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Trumpets C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Tuba C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
audio_path = librosa.util.example_audio_file()

audio_path = 'Desktop/PHYSICS/Pufferfish56/Audio Files No Beats/Vibraphone C4 2s.mp3'

y, sr = librosa.load(audio_path)
# Out:
# /Users/elenapeot/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

plt.title('mel power spectrogram')

plt.colorbar(format='%+02.0f dB')

plt.tight_layout()

# %%
f, Pxx_den = periodogram(y, sr)
plt.semilogy(f, Pxx_den)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()
